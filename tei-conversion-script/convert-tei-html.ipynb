# %%
import os

from bs4 import BeautifulSoup
from bs4 import element

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
filename = "Ms__1.xml"
root = BeautifulSoup(open("./tei/"+filename,
                          encoding="utf-8"),'xml')

# %%
# Map facs_# to proper folio page name
facs_to_folio = {}

for facs in root.find_all('facsimile'):
    facs_to_folio[facs['xml:id']] = facs.find('graphic')['url']
    #print(facs['xml:id'],' ',facs.find('graphic')['url'])

# %%
# Split the dataset by page
for p in root.find_all('p'):
    page_str = '<div id="currentPage">'
    # Split the page by lines
    for lb in p.find_all('lb'):
        reading_order = str(int(lb['n'].replace('N','')))
        
        # Append everything under one lb into a string and wrap in a div
        lb_string = '<div readingOrderIndex="'+reading_order+'">'
        
        # Walk through the contents of this line until the next line is found
        for sib in lb.next_siblings:
            if type(sib) == element.Tag:
                if sib.has_attr('n'):
                    break
                # Handle abbreviations
                if sib.name == 'choice':
                    # Handle rubrications inside abbrs
                    if sib.find('rubrication'):
                        inner_rubr = sib.find('rubrication')
                        abbr = str(sib.find('abbr'))
                    else:
                        abbr = sib.find('abbr').text
                        
                    expan = sib.find('expan').text
                    lb_string += '<span data-html="true" data-toggle="tooltip"\
                                        title="<em>' +expan+ '</em>">' +abbr+ '</span>'
                    continue
            lb_string += str(sib)
        lb_string += '</div>'
        page_str += lb_string
    page_str += '</div>'
    # Translate tags to HTML
    page_str = page_str.replace('<rubrication>','<span rubricated="true">')
    page_str = page_str.replace('</rubrication>','</span>')
    page_str = page_str.replace('<Drop-Capital>', '<span dropCap="true">')
    page_str = page_str.replace('</Drop-Capital>', '</span>')
    page_str = page_str.replace("\n",'')

    # Output newly built page to an html file
    try:
        filename = facs_to_folio[p['facs'].replace('_r1','').replace('#','')]
    except:
        print('Page ' +facs_to_folio[p['facs'].replace('_r1','').replace('#',
                            '').split('_region')[0].replace('_r2','').replace('_r3',
                                                                    '')]+ ' has a problem')
        continue

    with open("./output/" + filename.replace('.JPG','.html'), "wb") as outfile:
        outfile.write(page_str.encode("utf-8"))

    print('--------page successsful--------')
# Out:
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_4R.JPG has a problem
# Page ARC_manuscript_1_4R.JPG has a problem
# --------page successsful--------
# Page ARC_manuscript_1_5R.JPG has a problem
# --------page successsful--------
# Page ARC_manuscript_1_5V.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_9V.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_12R.JPG has a problem
# --------page successsful--------
# Page ARC_manuscript_1_13R.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_15R.JPG has a problem
# --------page successsful--------
# Page ARC_manuscript_1_16R.JPG has a problem
# --------page successsful--------
# Page ARC_manuscript_1_17R.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_19V.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_21V.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_23R.JPG has a problem
# Page ARC_manuscript_1_23R.JPG has a problem
# Page ARC_manuscript_1_23V.JPG has a problem
# Page ARC_manuscript_1_23V.JPG has a problem
# --------page successsful--------
# Page ARC_manuscript_1_24R.JPG has a problem
# Page ARC_manuscript_1_24V.JPG has a problem
# Page ARC_manuscript_1_24V.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_26V.JPG has a problem
# Page ARC_manuscript_1_27R.JPG has a problem
# Page ARC_manuscript_1_27R.JPG has a problem
# Page ARC_manuscript_1_27V.JPG has a problem
# Page ARC_manuscript_1_27V.JPG has a problem
# Page ARC_manuscript_1_27V.JPG has a problem
# Page ARC_manuscript_1_27V.JPG has a problem
# Page ARC_manuscript_1_27V.JPG has a problem
# Page ARC_manuscript_1_27V.JPG has a problem
# --------page successsful--------
# Page ARC_manuscript_1_28R.JPG has a problem
# Page ARC_manuscript_1_28R.JPG has a problem
# Page ARC_manuscript_1_28R.JPG has a problem
# Page ARC_manuscript_1_28R.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_29V.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_31V.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_38R.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_59R.JPG has a problem
# Page ARC_manuscript_1_59R.JPG has a problem
# Page ARC_manuscript_1_59R.JPG has a problem
# Page ARC_manuscript_1_59R.JPG has a problem
# Page ARC_manuscript_1_59R.JPG has a problem
# Page ARC_manuscript_1_59R.JPG has a problem
# Page ARC_manuscript_1_59R.JPG has a problem
# Page ARC_manuscript_1_59R.JPG has a problem
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_62R (bis).JPG has a problem
# --------page successsful--------
# --------page successsful--------
# --------page successsful--------
# Page ARC_manuscript_1_64R.JPG has a problem
# Page ARC_manuscript_1_65R.JPG has a problem
# Page ARC_manuscript_1_65V.JPG has a problem
